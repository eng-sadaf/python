# %% [markdown]
# # mpl_squares.py

# %%
import matplotlib.pyplot as plt

squares = [1, 4, 9, 16, 25]
fig, ax = plt.subplots()
ax.plot(squares)
plt.show()

# %%
import matplotlib.pyplot as plt

squares = [1, 4, 9, 16, 25]
fig, ax = plt.subplots()
ax.plot(squares, linewidth=7) #increaing line width
plt.show()

# %%
import matplotlib.pyplot as plt

squares = [1, 4, 9, 16, 25]
fig, ax = plt.subplots()
ax.plot(squares)

ax.set_title('Square Numbers', fontsize=24)
ax.set_xlabel('Values', fontsize=14)
ax.set_ylabel("Square of Values", fontsize=14)
ax.tick_params(axis='both', labelsize=10)


plt.show()

# %%
import matplotlib.pyplot as plt

input_value = [1, 2, 3, 4, 5]
squares = [1, 4, 9, 16, 25]

fig, ax = plt.subplots()
ax.plot(input_value, squares, linewidth=3) #correcting values to graph

plt.show()

# %%
#matplotlib styles
import matplotlib.pyplot as plt
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
import matplotlib.pyplot as plt

input_value = [1, 2, 3, 4, 5]
squares = [1, 4, 9, 16, 25]
plt.style.use('fivethirtyeight') #using any of the above styles

fig, ax = plt.subplots()
ax.plot(input_value, squares, linewidth=3)

ax.set_title('Square Numbers', fontsize=24)
ax.set_xlabel('Values', fontsize=14)
ax.set_ylabel("Square of Values", fontsize=14)
ax.tick_params(axis='both', labelsize=10)


plt.show()

# %% [markdown]
# # scatter_squares.py

# %%
#s=200 size of the dot in centre
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt

plt.style.use('seaborn-v0_8-notebook')
fig, ax = plt.subplots()
ax.scatter(2, 4, s=200)

ax.set_title("Square Numbers", fontsize=24)
ax.set_xlabel('Values', fontsize=14)
ax.set_ylabel('Sqaure of values', fontsize=14)

ax.tick_params(axis='both', which='major', labelsize=14)

plt.show()

# %% [markdown]
# # Plotting a Series of Points with scatter()

# %%
import matplotlib.pyplot as plt

x_values = [1, 2, 3, 4, 5]
y_values = [1, 4, 9, 16, 25]

plt.style.use('seaborn-v0_8-notebook')
fig, ax = plt.subplots()
ax.scatter(x_values, y_values, s=200) #scattering mutiple dots on points

ax.set_title("Square Numbers", fontsize=24)
ax.set_xlabel('Values', fontsize=14)
ax.set_ylabel('Sqaure of values', fontsize=14)

ax.tick_params(axis='both', which='major', labelsize=14)

plt.show()

# %% [markdown]
# # Calculating Data Automatically

# %%
import matplotlib.pyplot as plt

x_values = range(1,1001)
y_values = [x**2 for x in x_values]

plt.style.use('Solarize_Light2')
fig, ax = plt.subplots()
ax.scatter(x_values, y_values, s=10) #descreasing points size due to large data values
ax.axis([0, 1100, 0, 1100000])

ax.set_title("Square Numbers", fontsize=24)
ax.set_xlabel('Values', fontsize=14)
ax.set_ylabel('Sqaure of values', fontsize=14)

ax.tick_params(axis='both', which='major', labelsize=10)

plt.show()

# %% [markdown]
# # Defining Custom Colors

# %%
import matplotlib.pyplot as plt

x_values = [1, 2, 3, 4, 5]
y_values = [1, 4, 9, 16, 25]

plt.style.use('seaborn-v0_8-notebook')
fig, ax = plt.subplots()
ax.scatter(x_values, y_values, c='red', s=200) #changing color

ax.set_title("Square Numbers", fontsize=24)
ax.set_xlabel('Values', fontsize=14)
ax.set_ylabel('Sqaure of values', fontsize=14)

ax.tick_params(axis='both', which='major', labelsize=14)

plt.show()

# %%
import matplotlib.pyplot as plt

x_values = [1, 2, 3, 4, 5]
y_values = [1, 4, 9, 16, 25]

plt.style.use('seaborn-v0_8-notebook')
fig, ax = plt.subplots()
ax.scatter(x_values, y_values, c=(0, 0.8, 0), s=200) #changing color

ax.set_title("Square Numbers", fontsize=24)
ax.set_xlabel('Values', fontsize=14)
ax.set_ylabel('Sqaure of values', fontsize=14)

ax.tick_params(axis='both', which='major', labelsize=14)

plt.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %% [markdown]
# # Using a Colormap
# You can see all the colormaps available in pyplot at https://matplotlib.org/; go to
# Examples, scroll down to Color, and click Colormap reference.

# %%
import matplotlib.pyplot as plt

x_values = range(1,1001)
y_values = [x**2 for x in x_values]

plt.style.use('Solarize_Light2')
fig, ax = plt.subplots()
ax.scatter(x_values, y_values, c=y_values, cmap=plt.cm.Blues, s=10) #adding gradient color
ax.axis([0, 1100, 0, 1100000])

ax.set_title("Square Numbers", fontsize=24)
ax.set_xlabel('Values', fontsize=14)
ax.set_ylabel('Sqaure of values', fontsize=14)

ax.tick_params(axis='both', which='major', labelsize=10)

plt.show()

# %% [markdown]
# # Saving Your Plots Automatically
# replace the call to plt.show() with a call to plt.savefig():
# (check file in tha same directory)

# %%
import matplotlib.pyplot as plt

x_values = range(1,1001)
y_values = [x**2 for x in x_values]

plt.style.use('Solarize_Light2')
fig, ax = plt.subplots()
ax.scatter(x_values, y_values, c=y_values, cmap=plt.cm.Blues, s=10) 
ax.axis([0, 1100, 0, 1100000])

ax.set_title("Square Numbers", fontsize=24)
ax.set_xlabel('Values', fontsize=14)
ax.set_ylabel('Sqaure of values', fontsize=14)

ax.tick_params(axis='both', which='major', labelsize=10)

plt.savefig('squares_plot.png', bbox_inches='tight') #second argumemt to remove extra white space

# %% [markdown]
# # Random Walks

# %%
import matplotlib.pyplot as plt
from random_walk import RandomWalk

rw = RandomWalk()
rw.fill_walk()

plt.style.use('Solarize_Light2')
fig, ax = plt.subplots()
ax.scatter(rw.x_values, rw.y_values, s=10)
plt.show()

# %% [markdown]
# # Generating Multiple Random Walks

# %%
import matplotlib.pyplot as plt
from random_walk import RandomWalk

while True:
    rw = RandomWalk()
    rw.fill_walk()

    plt.style.use('Solarize_Light2')
    fig, ax = plt.subplots()
    ax.scatter(rw.x_values, rw.y_values, s=10)
    plt.show()

    keep_running = input("Make another walk? (y/n): ")
    if keep_running == 'n':
        break
# Out:
# Make another walk? (y/n): y
# Make another walk? (y/n): y
# Make another walk? (y/n): n

# %% [markdown]
# # Styling the Walk
# Coloring the Points

# %%
import matplotlib.pyplot as plt
from random_walk import RandomWalk

while True:
    rw = RandomWalk()
    rw.fill_walk()
    
    plt.style.use('Solarize_Light2')
    fig, ax = plt.subplots()
    point_numbers = range(rw.num_points)
    ax.scatter(rw.x_values, rw.y_values, c=point_numbers, cmap=plt.cm.Blues, edgecolor='none', s=15)
    plt.show()
    
    keep_running = input("Make another walk? (y/n): ")
    if keep_running == 'n':
        break
# Out:
# Make another walk? (y/n): y
# Make another walk? (y/n): v
# Make another walk? (y/n): d
# Make another walk? (y/n): s

# %% [markdown]
# # Plotting the Starting and Ending Points

# %%
import matplotlib.pyplot as plt
from random_walk import RandomWalk

while True:
    rw = RandomWalk()
    rw.fill_walk()
    
    plt.style.use('Solarize_Light2')
    fig, ax = plt.subplots()
    point_numbers = range(rw.num_points)
    ax.scatter(rw.x_values, rw.y_values, c=point_numbers, cmap=plt.cm.Blues, edgecolor='none', s=15)
    ax.scatter(0, 0, c='green', edgecolor='none', s=200)
    ax.scatter(rw.x_values[-1], rw.y_values[-1], c='red', edgecolor='none', s=200)
    plt.show()
    
    keep_running = input("Make another walk? (y/n): ")
    if keep_running == 'n':
        break
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [7], in <cell line: 5>()
#      13 ax.scatter(rw.x_values[-1], rw.y_values[-1], c='red', edgecolor='none', s=200)
#      14 plt.show()
# ---> 16 keep_running = input("Make another walk? (y/n): ")
#      17 if keep_running == 'n':
#      18     break
#
# File ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py:1075, in Kernel.raw_input(self, prompt)
#    1071 if not self._allow_stdin:
#    1072     raise StdinNotImplementedError(
#    1073         "raw_input was called, but this frontend does not support input requests."
#    1074     )
# -> 1075 return self._input_request(
#    1076     str(prompt),
#    1077     self._parent_ident["shell"],
#    1078     self.get_parent("shell"),
#    1079     password=False,
#    1080 )
#
# ...

# %% [markdown]
# # Cleaning Up the Axes

# %%
import matplotlib.pyplot as plt
from random_walk import RandomWalk

while True:
    rw = RandomWalk()
    rw.fill_walk()
    
    plt.style.use('Solarize_Light2')
    fig, ax = plt.subplots()
    point_numbers = range(rw.num_points)
    ax.scatter(rw.x_values, rw.y_values, c=point_numbers, cmap=plt.cm.Blues, edgecolor='none', s=15)
    ax.scatter(0, 0, c='green', edgecolor='none', s=200)
    ax.scatter(rw.x_values[-1], rw.y_values[-1], c='red', edgecolor='none', s=200)
    
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    
    plt.show()
    
    keep_running = input("Make another walk? (y/n): ")
    if keep_running == 'n':
        break
# Out:
# Make another walk? (y/n): n

# %%
import matplotlib.pyplot as plt
from random_walk import RandomWalk

while True:
    rw = RandomWalk(50_000)
    rw.fill_walk()
    
    plt.style.use('Solarize_Light2')
    fig, ax = plt.subplots()
    point_numbers = range(rw.num_points)
    ax.scatter(rw.x_values, rw.y_values, c=point_numbers, cmap=plt.cm.Blues, edgecolor='none', s=1)
    ax.scatter(0, 0, c='green', edgecolor='none', s=100)
    ax.scatter(rw.x_values[-1], rw.y_values[-1], c='red', edgecolor='none', s=100)
    plt.show()
    
    keep_running = input("Make another walk? (y/n): ")
    if keep_running == 'n':
        break
# Out:
# Make another walk? (y/n): n

# %%
import matplotlib.pyplot as plt
from random_walk import RandomWalk

while True:
    rw = RandomWalk(50_000)
    rw.fill_walk()
    
    plt.style.use('Solarize_Light2')
    fig, ax = plt.subplots(figsize=(10,6), dpi=128)
    point_numbers = range(rw.num_points)
    ax.scatter(rw.x_values, rw.y_values, c=point_numbers, cmap=plt.cm.Blues, edgecolor='none', s=10)
    ax.scatter(0, 0, c='green', edgecolor='none', s=100)
    ax.scatter(rw.x_values[-1], rw.y_values[-1], c='red', edgecolor='none', s=100)
    plt.show()
    
    keep_running = input("Make another walk? (y/n): ")
    if keep_running == 'n':
        break
# Out:
# Make another walk? (y/n): n

# %% [markdown]
# # Rolling Dice with Plotly
# Plotly is particularly useful when you’re creating visualizations that will be displayed in a browser, because the visualizations will scale automatically to fit the viewer’s screen.

# %%
#(vscode Analyzing the Resultsdie.py)

# %%
#die_visual.py
from die import Die

die = Die()
results = []
for roll_num in range(100):
    result = die.roll()
    results.append(result)
    
print(results)
# Out:
# [4, 1, 5, 1, 3, 1, 6, 3, 5, 5, 5, 1, 4, 6, 5, 3, 4, 6, 1, 6, 1, 5, 3, 1, 6, 5, 4, 6, 2, 3, 3, 2, 5, 5, 4, 2, 4, 4, 4, 1, 6, 4, 5, 5, 2, 6, 5, 5, 2, 3, 5, 3, 1, 6, 1, 1, 4, 2, 1, 6, 6, 6, 4, 4, 4, 3, 6, 1, 2, 5, 6, 4, 2, 6, 5, 5, 2, 3, 5, 4, 3, 1, 4, 6, 6, 2, 5, 2, 3, 1, 1, 2, 2, 4, 6, 5, 6, 3, 6, 1]

# %% [markdown]
# # Analyzing the Results

# %%
#die_visual.py
from die import Die

die = Die()
results = []
for roll_num in range(1000):
    result = die.roll()
    results.append(result)

frequencies = []
for value in range(1,die.num_sides+1):
    frequency = results.count(value)
    frequencies.append(frequency)
    
print(frequencies)
# Out:
# [187, 178, 181, 160, 137, 157]

# %%
Making a Histogram

# %%
#die_visual.py
from die import Die
from plotly.graph_objs import Bar,Layout
from plotly import offline

die = Die()
results = []
for roll_num in range(1000):
    result = die.roll()
    results.append(result)
    
frequencies = []
for value in range(1, die.num_sides+1):
    frequency = results.count(value)
    frequencies.append(frequency)
    
x_value = list(range(1,die.num_sides+1))
data = [Bar(x=x_value, y=frequencies)]

x_axis_config = {'title':'Result'}
y_axis_config = {'title':'frequency of Result'}
my_layout = Layout(title='Result of rolling one D6 1000 times', xaxis = x_axis_config, yaxis = y_axis_config)

offline.plot({'data':data, 'layout':my_layout}, filename='d6.html')
# Out:
# 'd6.html'

# %% [markdown]
# # Rolling two dices

# %%
from plotly.graph_objs import Bar, Layout
from plotly import offline
from die import Die

die_1 = Die()
die_2 = Die()

results = []
for roll_num in range(1000):
    result = die_1.roll() + die_2.roll()
    results.append(result)
    
frequencies = []
max_result = die_1.num_sides + die_2.num_sides
for value in range(2,max_result+1):
    frequency = results.count(value)
    frequencies.append(frequency)
    
x_value = list(range(2,max_result+1))
data = [Bar(x=x_value, y=frequencies)]

x_axis_config = {'title':'Result', 'dtick':1}
y_axis_config = {'title':'Frequency of Result'}
my_layout = Layout(title='Results of rolling two D6 dice 1000 times', 
                   xaxis=x_axis_config, yaxis=y_axis_config)
offline.plot({'data': data, 'layout': my_layout}, filename='d6_d6.html')
# Out:
# 'd6_d6.html'

# %% [markdown]
# # Rolling Dice of Different Sizes
# Let’s create a six-sided die and a ten-sided die, and see what happens when we roll them 50,000 times:

# %%
from plotly.graph_objs import Bar, Layout
from plotly import offline
from die import Die

die_1 = Die()
die_2 = Die(10)

results = []
for roll_num in range(50_000):
    result = die_1.roll() + die_2.roll()
    results.append(result)
    
frequencies = []
max_result = die_1.num_sides + die_2.num_sides
for value in range(2,max_result+1):
    frequency = results.count(value)
    frequencies.append(frequency)
    
x_value = list(range(2,max_result+1))
data = [Bar(x=x_value, y=frequencies)]

x_axis_config = {'title':'Result'}
y_axis_config = {'title':'Frequncy of Result'}
my_layout = Layout(title='Result of rolling two D6 and D10 dice 50,000 times',
                  xaxis=x_axis_config, yaxis=y_axis_config)
offline.plot({'data': data, 'layout': my_layout}, filename='d6_d10.html')
# Out:
# 'd6_d10.html'
